# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos (como veremos no caso do SMS) vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json
from pprint import pprint
url = "https://economia.awesomeapi.com.br/json/all"

cotacoes = requests.get(url)
cotacoes_dic = cotacoes.json()
pprint(cotacoes_dic)
# Out:
# {'ARS': {'ask': '0.0061',
#          'bid': '0.0061',
#          'code': 'ARS',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:21',
#          'high': '0.0062',
#          'low': '0.006',
#          'name': 'Peso Argentino/Real Brasileiro',
#          'pctChange': '1.66',
#          'timestamp': '1719857781',
#          'varBid': '0.0001'},
#  'AUD': {'ask': '3.7381',
#          'bid': '3.7332',
#          'code': 'AUD',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:25',
#          'high': '3.7388',
#          'low': '3.6583',
#          'name': 'Dólar Australiano/Real Brasileiro',
#          'pctChange': '1.95',
#          'timestamp': '1719857785',
#          'varBid': '0.0716'},
#  'BTC': {'ask': '357700',
#          'bid': '357283',
#          'code': 'BTC',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:15:21',
#          'high': '357700',
#          'low': '345994',
#          'name': 'Bitcoin/Real Brasileiro',
#          'pctChange': '3.13',
#          'timestamp': '1719857721',
#          'varBid': '10852'},
#  'CAD': {'ask': '4.0884',
#          'bid': '4.083',
#          'code': 'CAD',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:09',
#          'high': '4.0919',
#          'low': '4.0096',
#          'name': 'Dólar Canadense/Real Brasileiro',
#          'pctChange': '1.63',
#          'timestamp': '1719857769',
#          'varBid': '0.0657'},
#  'CHF': {'ask': '6.2163',
#          'bid': '6.208',
#          'code': 'CHF',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:21',
#          'high': '6.2235',
#          'low': '6.0956',
#          'name': 'Franco Suíço/Real Brasileiro',
#          'pctChange': '1.6',
#          'timestamp': '1719857781',
#          'varBid': '0.0976'},
#  'CNY': {'ask': '0.7726',
#          'bid': '0.7726',
#          'code': 'CNY',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:03',
#          'high': '0.7735',
#          'low': '0.7661',
#          'name': 'Yuan Chinês/Real Brasileiro',
#          'pctChange': '0.37',
#          'timestamp': '1719857763',
#          'varBid': '0.0028'},
#  'DOGE': {'ask': '0.7062',
#           'bid': '0.7062',
#           'code': 'DOGE',
#           'codein': 'BRL',
#           'create_date': '2024-07-01 15:12:23',
#           'high': '0.7111',
#           'low': '0.6857',
#           'name': 'Dogecoin/Real Brasileiro',
#           'pctChange': '2.97',
#           'timestamp': '1719857543',
#           'varBid': '0.0204'},
#  'ETH': {'ask': '19655.05',
#          'bid': '19574.95',
#          'code': 'ETH',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:23',
#          'high': '19744.45',
#          'low': '19145.35',
#          'name': 'Ethereum/Real Brasileiro',
#          'pctChange': '2.26',
#          'timestamp': '1719857783',
#          'varBid': '433.74'},
#  'EUR': {'ask': '6.0276',
#          'bid': '6.0196',
#          'code': 'EUR',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:17',
#          'high': '6.0303',
#          'low': '5.8917',
#          'name': 'Euro/Real Brasileiro',
#          'pctChange': '2.24',
#          'timestamp': '1719857777',
#          'varBid': '0.1319'},
#  'GBP': {'ask': '7.0983',
#          'bid': '7.0945',
#          'code': 'GBP',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:09',
#          'high': '7.1037',
#          'low': '7.0447',
#          'name': 'Libra Esterlina/Real Brasileiro',
#          'pctChange': '0.3',
#          'timestamp': '1719857769',
#          'varBid': '0.0212'},
#  'ILS': {'ask': '1.492',
#          'bid': '1.4918',
#          'code': 'ILS',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:05',
#          'high': '1.4945',
#          'low': '1.4807',
#          'name': 'Novo Shekel Israelense/Real Brasileiro',
#          'pctChange': '0.53',
#          'timestamp': '1719857765',
#          'varBid': '0.0079'},
#  'JPY': {'ask': '0.03478',
#          'bid': '0.03476',
#          'code': 'JPY',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:15',
#          'high': '0.0348',
#          'low': '0.03416',
#          'name': 'Iene Japonês/Real Brasileiro',
#          'pctChange': '1.76',
#          'timestamp': '1719857775',
#          'varBid': '0.0006'},
#  'LTC': {'ask': '424.2',
#          'bid': '422',
#          'code': 'LTC',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:04:34',
#          'high': '426.69',
#          'low': '413.05',
#          'name': 'Litecoin/Real Brasileiro',
#          'pctChange': '1.68',
#          'timestamp': '1719857074',
#          'varBid': '6.98'},
#  'USD': {'ask': '5.6177',
#          'bid': '5.6165',
#          'code': 'USD',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:16:22',
#          'high': '5.622',
#          'low': '5.567',
#          'name': 'Dólar Americano/Real Brasileiro',
#          'pctChange': '0.44',
#          'timestamp': '1719857782',
#          'varBid': '0.0246'},
#  'USDT': {'ask': '5.81',
#           'bid': '5.48',
#           'code': 'USD',
#           'codein': 'BRLT',
#           'create_date': '2024-07-01 15:12:00',
#           'high': '5.65',
#           'low': '5.58',
#           'name': 'Dólar Americano/Real Brasileiro Turismo',
#           'pctChange': '0.44',
#           'timestamp': '1719857520',
#           'varBid': '0.025'},
#  'XRP': {'ask': '2.69',
#          'bid': '2.68',
#          'code': 'XRP',
#          'codein': 'BRL',
#          'create_date': '2024-07-01 15:15:23',
#          'high': '2.71',
#          'low': '2.66',
#          'name': 'XRP/Real Brasileiro',
#          'pctChange': '0.96',
#          'timestamp': '1719857723',
#          'varBid': '0.03'}}

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin? (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar (Sua resposta vai dar diferente do gabarito, porque estamos rodando o código em momentos diferentes, mas o seu código deve ser o mesmo/parecido)

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %% [markdown]
# #### Gráfico com as cotações do BitCoin

# %% [markdown]
# # Comparando, Tratando e Mesclando DataFrames
#
# ## Objetivo
#
# Vamos modificar os IDs para os nomes dos produtos, dos clientes e das lojas, para nossas análises ficarem mais intuitivas futuramente. Para isso, vamos criar um data frame com todos os detalhes.
#
# - Usaremos o método merge para isso e, depois se quisermos, podemos pegar apenas as colunas que queremos do dataframe final.

# %% [markdown]
# ### Criando nossos dataframes

# %%
import pandas as pd

#às vezes precisaremos mudar o encoding. Possiveis valores para testar:
#encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'
vendas_df    = pd.read_csv(r'.\Pandas 05 - Dados\Contoso - Vendas - 2017.csv', sep=';', encoding='utf-8')
produtos_df  = pd.read_csv(r'.\Pandas 05 - Dados\Contoso - Cadastro Produtos.csv', sep=';', encoding='ANSI')
lojas_df     = pd.read_csv(r'.\Pandas 05 - Dados\Contoso - Lojas.csv', sep=';', encoding='ANSI')
clientes_df  = pd.read_csv(r'.\Pandas 05 - Dados\Contoso - Clientes.csv', sep=';', encoding='ANSI')
promocoes_df = pd.read_csv(r'.\Pandas 05 - Dados\Contoso - Promocoes.csv', sep=';', encoding='ANSI')


#usaremos o display para ver todos os dataframes
display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
display(promocoes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0              981            2        6825                   9
# 1             1586            2       18469                   9
# 2             1444            5       19730                  13
# 3             1468            5       29326                   6
# 4             1106            2       22617                   4
# ...            ...          ...         ...                 ...
# 980637        2490            4       10353                 120
# 980638        2488            4       31750                 120
# 980639        2511           10       12003                  80
# 980640         436            4       25550                  39
# 980641        2510           10       28707                  80
#
#         Quantidade Devolvida
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ...                      ...
# 980637                     0
# 980638                     0
# 980639                     0
# 980640                     0
# 980641                     0
#
# [980642 rows x 10 columns]
#                                       Nome do Produto  \
# 0               Contoso Wireless Laser Mouse E50 Grey
# 1       Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2      Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3      Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4     Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...                                               ...
# 1685        SV DVD 12-Inch Player Portable M400 Black
# 1686        SV DVD 9-Inch Player Portable M300 Silver
# 1687       SV DVD 12-Inch Player Portable M400 Silver
# 1688         SV DVD 9-Inch Player Portable M300 White
# 1689        SV DVD 12-Inch Player Portable M400 White
#
#                                    Descricao do Produto        Fabricante  \
# 0     Advanced 2.4 GHz cordless technology makes fre...      Contoso, Ltd
# 1                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 2                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 3                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# 4                        PS/2 mouse, 6 feet mouse cable      Contoso, Ltd
# ...                                                 ...               ...
# 1685  6-hour rechargeable battery, 180-degree swivel...  Southridge Video
# 1686  6-hour rechargeable battery, 180-degree swivel...  Southridge Video
# 1687  6-hour rechargeable battery, 180-degree swivel...  Southridge Video
# 1688  6-hour rechargeable battery, 180-degree swivel...  Southridge Video
# 1689  6-hour rechargeable battery, 180-degree swivel...  Southridge Video
#
#          Nome da Marca      Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0              Contoso  Econ?ico          10,69          20,96         873
# 1              Contoso  Econ?ico           6,63             13         879
# 2              Contoso  Econ?ico           6,63             13         880
# 3              Contoso  Econ?ico           6,63             13         881
# 4              Contoso  Econ?ico           6,63             13         882
# ...                ...       ...            ...            ...         ...
# 1685  Southridge Video   Regular          82,77         179,99        1602
# 1686  Southridge Video   Regular          73,57         159,99        1606
# 1687  Southridge Video   Regular          82,77         179,99        1607
# 1688  Southridge Video   Regular          73,57         159,99        1611
# 1689  Southridge Video   Regular          82,77         179,99        1612
#
#       ID Subcategoria
# 0                22.0
# 1                22.0
# 2                22.0
# 3                22.0
# 4                22.0
# ...               ...
# 1685             35.0
# 1686             35.0
# 1687             35.0
# 1688             35.0
# 1689             35.0
#
# [1690 rows x 9 columns]
#      ID Loja                         Nome da Loja  Quantidade Colaboradores  \
# 0          1           Loja Contoso Seattle No.1                       17.0
# 1          2           Loja Contoso Seattle No.2                       25.0
# 2          3              Loja Contoso Kennewick                       26.0
# 3          4               Loja Contoso Bellevue                       19.0
# 4          5                Loja Contoso Redmond                       33.0
# ..       ...                                  ...                       ...
# 301      306          Loja Contoso Europe Online                        7.0
# 302      307            Loja Contoso Asia Online                        8.0
# 303      308  Loja Contoso North America Reseller                      15.0
# 304      309         Loja Contoso Europe Reseller                      12.0
# 305      310           Loja Contoso Asia Reseller                      17.0
#
#                País
# 0    Estados Unidos
# 1    Estados Unidos
# 2    Estados Unidos
# 3    Estados Unidos
# 4    Estados Unidos
# ..              ...
# 301        Alemanha
# 302           China
# 303  Estados Unidos
# 304          França
# 305           China
#
# [306 rows x 4 columns]
#        ID Cliente Primeiro Nome     Sobrenome                         E-mail  \
# 0               1        Garnet    Lanfranchi    glanfranchi0@mayoclinic.com
# 1               2       Lurette     Roseblade      lroseblade1@bigcartel.com
# 2               3       Glenden     Ishchenko      gishchenko2@moonfruit.com
# 3               4         Baron  Jedrzejewsky    bjedrzejewsky3@e-recht24.de
# 4               5        Sheree      Bredbury       sbredbury4@sitemeter.com
# ...           ...           ...           ...                            ...
# 39499       39500        Brandy      Malhotra    brandy0@adventure-works.com
# 39500       39501        Alicia          Raje   alicia12@adventure-works.com
# 39501       39502        Connie           Rai    connie4@adventure-works.com
# 39502       39503         Shawn          Raji    shawn23@adventure-works.com
# 39503       39504       Lindsey        Sharma  lindsey10@adventure-works.com
#
#           Genero Numero de Filhos Data de Nascimento
# 0       Feminino                2         12/05/1995
# 1       Feminino                2         30/06/1943
# 2      Masculino                5         09/04/1989
# 3      Masculino                4         17/11/1998
# 4       Feminino                5         08/09/1975
# ...          ...              ...                ...
# 39499  Masculino                3         27/07/1980
# 39500   Feminino                5         10/05/2001
# 39501   Feminino                0         13/02/1997
# 39502  Masculino                1         29/03/2001
# 39503   Feminino                0         19/11/1961
#
# [39504 rows x 7 columns]
#     ID Promocao                         Nome Promocao Percentual Desconto  \
# 0             1                          Sem desconto                   0
# 1             2       Promoção de Primavera Americana                0,05
# 2             3    Promoção Volta às Aulas Americanas                 0,1
# 3             4  Promoção Férias Escolares Americanas                 0,2
# 4             5             Promoção Férias Asiáticas                0,15
# 5             6        Promoção de Primavera Asiática                 0,2
# 6             7            Promoção de Verão Asiático                 0,1
# 7             8        Promoção de Primavera Europeia                0,07
# 8             9     Promoção Volta às Aulas Europeias                 0,1
# 9            10          Promoção de Férias Europeias                 0,2
# 10           11       Promoção de Primavera Americana                0,05
# 11           12    Promoção Volta às Aulas Americanas                 0,1
# 12           13  Promoção Férias Escolares Americanas                 0,2
# 13           14             Promoção Férias Asiáticas                0,15
# 14           15        Promoção de Primavera Asiática                 0,2
# 15           16            Promoção de Verão Asiático                 0,1
# 16           17        Promoção de Primavera Europeia                0,07
# 17           18     Promoção Volta às Aulas Europeias                 0,1
# 18           19          Promoção de Férias Europeias                 0,2
# 19           20       Promoção de Primavera Americana                0,05
# 20           21    Promoção Volta às Aulas Americanas                 0,1
# 21           22  Promoção Férias Escolares Americanas                 0,2
# 22           23             Promoção Férias Asiáticas                0,15
# 23           24        Promoção de Primavera Asiática                 0,2
# 24           25            Promoção de Verão Asiático                 0,1
# 25           26        Promoção de Primavera Europeia                0,07
# 26           27     Promoção Volta às Aulas Europeias                 0,1
# 27           28          Promoção de Férias Europeias                 0,2
#
#    Data Inicio Data Termino
# 0   01/01/2017   31/12/2020
# 1   01/01/2017   31/03/2017
# 2   01/07/2017   30/09/2017
# 3   01/11/2017   31/12/2017
# 4   01/11/2017   31/01/2018
# 5   01/02/2017   30/04/2017
# 6   01/05/2017   30/06/2017
# 7   01/02/2017   30/04/2017
# 8   01/08/2017   30/09/2017
# 9   01/10/2017   31/01/2018
# 10  01/01/2018   31/03/2018
# 11  01/07/2018   30/09/2018
# 12  01/11/2018   31/12/2018
# 13  01/11/2018   31/01/2019
# 14  01/02/2018   30/04/2018
# 15  01/05/2018   30/06/2018
# 16  01/02/2018   30/04/2018
# 17  01/08/2018   30/09/2018
# 18  01/10/2018   31/01/2019
# 19  01/01/2019   31/03/2020
# 20  01/07/2019   30/09/2019
# 21  01/11/2019   31/12/2019
# 22  01/11/2019   31/01/2020
# 23  01/02/2019   30/04/2019
# 24  01/05/2019   30/06/2019
# 25  01/02/2019   30/04/2019
# 26  01/08/2019   30/09/2019
# 27  01/10/2019   31/01/2020

# %% [markdown]
# ### Vamos tirar as colunas inúteis do clientes_df ou pegar apenas as colunas que quisermos

# %% [raw]
# .drop([coluna1, coluna2, coluna3]) -> retira as colunas: coluna1, coluna2, coluna3

# %%
# clientes_df = clientes_df.drop(columns=['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'])
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]
promocoes_df = promocoes_df[['ID Promocao', 'Nome Promocao']]
display(clientes_df)
display(produtos_df)
display(lojas_df)
display(promocoes_df)
# Out:
#        ID Cliente                         E-mail
# 0               1    glanfranchi0@mayoclinic.com
# 1               2      lroseblade1@bigcartel.com
# 2               3      gishchenko2@moonfruit.com
# 3               4    bjedrzejewsky3@e-recht24.de
# 4               5       sbredbury4@sitemeter.com
# ...           ...                            ...
# 39499       39500    brandy0@adventure-works.com
# 39500       39501   alicia12@adventure-works.com
# 39501       39502    connie4@adventure-works.com
# 39502       39503    shawn23@adventure-works.com
# 39503       39504  lindsey10@adventure-works.com
#
# [39504 rows x 2 columns]
#       ID Produto                                  Nome do Produto
# 0            873            Contoso Wireless Laser Mouse E50 Grey
# 1            879    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2            880   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3            881   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4            882  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...          ...                                              ...
# 1685        1602        SV DVD 12-Inch Player Portable M400 Black
# 1686        1606        SV DVD 9-Inch Player Portable M300 Silver
# 1687        1607       SV DVD 12-Inch Player Portable M400 Silver
# 1688        1611         SV DVD 9-Inch Player Portable M300 White
# 1689        1612        SV DVD 12-Inch Player Portable M400 White
#
# [1690 rows x 2 columns]
#      ID Loja                         Nome da Loja
# 0          1           Loja Contoso Seattle No.1
# 1          2           Loja Contoso Seattle No.2
# 2          3              Loja Contoso Kennewick
# 3          4               Loja Contoso Bellevue
# 4          5                Loja Contoso Redmond
# ..       ...                                  ...
# 301      306          Loja Contoso Europe Online
# 302      307            Loja Contoso Asia Online
# 303      308  Loja Contoso North America Reseller
# 304      309         Loja Contoso Europe Reseller
# 305      310           Loja Contoso Asia Reseller
#
# [306 rows x 2 columns]
#     ID Promocao                         Nome Promocao
# 0             1                          Sem desconto
# 1             2       Promoção de Primavera Americana
# 2             3    Promoção Volta às Aulas Americanas
# 3             4  Promoção Férias Escolares Americanas
# 4             5             Promoção Férias Asiáticas
# 5             6        Promoção de Primavera Asiática
# 6             7            Promoção de Verão Asiático
# 7             8        Promoção de Primavera Europeia
# 8             9     Promoção Volta às Aulas Europeias
# 9            10          Promoção de Férias Europeias
# 10           11       Promoção de Primavera Americana
# 11           12    Promoção Volta às Aulas Americanas
# 12           13  Promoção Férias Escolares Americanas
# 13           14             Promoção Férias Asiáticas
# 14           15        Promoção de Primavera Asiática
# 15           16            Promoção de Verão Asiático
# 16           17        Promoção de Primavera Europeia
# 17           18     Promoção Volta às Aulas Europeias
# 18           19          Promoção de Férias Europeias
# 19           20       Promoção de Primavera Americana
# 20           21    Promoção Volta às Aulas Americanas
# 21           22  Promoção Férias Escolares Americanas
# 22           23             Promoção Férias Asiáticas
# 23           24        Promoção de Primavera Asiática
# 24           25            Promoção de Verão Asiático
# 25           26        Promoção de Primavera Europeia
# 26           27     Promoção Volta às Aulas Europeias
# 27           28          Promoção de Férias Europeias

# %% [markdown]
# ### Agora vamos juntar os dataframes para ter 1 único dataframe com tudo "bonito"

# %% [raw]
# novo_dataframe = dataframe1.merge(dataframe2, on='coluna')

# %% [markdown]
# - Obs: O merge precisa das colunas com o mesmo nome para funcionar. Se não tiver, você precisa alterar o nome da coluna com o .rename

# %% [raw]
# dataframe.rename({'coluna1': 'novo_coluna_1'})

# %%
#juntando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto').merge(lojas_df, on='ID Loja').merge(clientes_df, on='ID Cliente').merge(promocoes_df, on='ID Promocao')
vendas_df = vendas_df.drop(columns=['ID Loja', 'ID Produto', 'ID Promocao'])

#exibindo o dataframe final
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Cliente  \
# 0                     1    01/01/2017    02/01/2017         1        6825
# 1                     2    01/01/2017    06/01/2017         5       18469
# 2                     3    01/01/2017    01/01/2017         0       19730
# 3                     4    01/01/2017    01/01/2017         0       29326
# 4                     5    01/01/2017    07/01/2017         6       22617
# ...                 ...           ...           ...       ...         ...
# 971360           980638    31/12/2017    31/12/2017         0       10353
# 971361           980639    31/12/2017    06/01/2018         6       31750
# 971362           980640    31/12/2017    03/01/2018         3       12003
# 971363           980641    31/12/2017    31/12/2017         0       25550
# 971364           980642    31/12/2017    31/12/2017         0       28707
#
#         Quantidade Vendida  Quantidade Devolvida  \
# 0                        9                     1
# 1                        9                     1
# 2                       13                     1
# 3                        6                     1
# 4                        4                     1
# ...                    ...                   ...
# 971360                 120                     0
# 971361                 120                     0
# 971362                  80                     0
# 971363                  39                     0
# 971364                  80                     0
#
#                                           Nome do Produto  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1                   SV DVD 55DVD Storage Binder M56 Black
# 2       The Phone Company Touch Screen Phones 26-2.2" ...
# 3             Contoso Touch Screen Phones - CRT M11 Black
# 4                          Contoso SLR Camera M146 Orange
# ...                                                   ...
# 971360      Contoso Rubberized Skin BlackBerry E100 White
# 971361      Contoso Rubberized Skin BlackBerry E100 Black
# 971362  Contoso Original K1m Li-Ion Standard Battery E...
# 971363         Adventure Works Desktop PC1.80 ED180 White
# 971364  Contoso Original K1m Li-Ion Standard Battery E...
#
#                                Nome da Loja                        E-mail  \
# 0                      Loja Contoso Austin         rbrumfieldmy@ameblo.jp
# 1       Loja Contoso North America Reseller        cshawd4@technorati.com
# 2                 Loja Contoso Tehran No.2         kgorriekd@bandcamp.com
# 3                   Loja Contoso Singapore   angela49@adventure-works.com
# 4               Loja Contoso Grand Prairie     jacob4@adventure-works.com
# ...                                     ...                           ...
# 971360                Loja Contoso Ridgely        ocrosson9u@illinois.edu
# 971361               Loja Contoso Milliken   victor11@adventure-works.com
# 971362               Loja Contoso Cheshire               mtopaz4@gmpg.org
# 971363              Loja Contoso East Troy     lance5@adventure-works.com
# 971364         Loja Contoso Europe Reseller      jan8@adventure-works.com
#
#                                Nome Promocao
# 0            Promoção de Primavera Americana
# 1            Promoção de Primavera Americana
# 2                  Promoção Férias Asiáticas
# 3                  Promoção Férias Asiáticas
# 4            Promoção de Primavera Americana
# ...                                      ...
# 971360  Promoção Férias Escolares Americanas
# 971361  Promoção Férias Escolares Americanas
# 971362          Promoção de Férias Europeias
# 971363  Promoção Férias Escolares Americanas
# 971364          Promoção de Férias Europeias
#
# [971365 rows x 11 columns]

# %%
#vamos renomear o e-mail para ficar claro que é do cliente
vendas_df = vendas_df.rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Cliente  \
# 0                     1    01/01/2017    02/01/2017         1        6825
# 1                     2    01/01/2017    06/01/2017         5       18469
# 2                     3    01/01/2017    01/01/2017         0       19730
# 3                     4    01/01/2017    01/01/2017         0       29326
# 4                     5    01/01/2017    07/01/2017         6       22617
# ...                 ...           ...           ...       ...         ...
# 971360           980638    31/12/2017    31/12/2017         0       10353
# 971361           980639    31/12/2017    06/01/2018         6       31750
# 971362           980640    31/12/2017    03/01/2018         3       12003
# 971363           980641    31/12/2017    31/12/2017         0       25550
# 971364           980642    31/12/2017    31/12/2017         0       28707
#
#         Quantidade Vendida  Quantidade Devolvida  \
# 0                        9                     1
# 1                        9                     1
# 2                       13                     1
# 3                        6                     1
# 4                        4                     1
# ...                    ...                   ...
# 971360                 120                     0
# 971361                 120                     0
# 971362                  80                     0
# 971363                  39                     0
# 971364                  80                     0
#
#                                           Nome do Produto  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1                   SV DVD 55DVD Storage Binder M56 Black
# 2       The Phone Company Touch Screen Phones 26-2.2" ...
# 3             Contoso Touch Screen Phones - CRT M11 Black
# 4                          Contoso SLR Camera M146 Orange
# ...                                                   ...
# 971360      Contoso Rubberized Skin BlackBerry E100 White
# 971361      Contoso Rubberized Skin BlackBerry E100 Black
# 971362  Contoso Original K1m Li-Ion Standard Battery E...
# 971363         Adventure Works Desktop PC1.80 ED180 White
# 971364  Contoso Original K1m Li-Ion Standard Battery E...
#
#                                Nome da Loja             E-mail do Cliente  \
# 0                      Loja Contoso Austin         rbrumfieldmy@ameblo.jp
# 1       Loja Contoso North America Reseller        cshawd4@technorati.com
# 2                 Loja Contoso Tehran No.2         kgorriekd@bandcamp.com
# 3                   Loja Contoso Singapore   angela49@adventure-works.com
# 4               Loja Contoso Grand Prairie     jacob4@adventure-works.com
# ...                                     ...                           ...
# 971360                Loja Contoso Ridgely        ocrosson9u@illinois.edu
# 971361               Loja Contoso Milliken   victor11@adventure-works.com
# 971362               Loja Contoso Cheshire               mtopaz4@gmpg.org
# 971363              Loja Contoso East Troy     lance5@adventure-works.com
# 971364         Loja Contoso Europe Reseller      jan8@adventure-works.com
#
#                                Nome Promocao
# 0            Promoção de Primavera Americana
# 1            Promoção de Primavera Americana
# 2                  Promoção Férias Asiáticas
# 3                  Promoção Férias Asiáticas
# 4            Promoção de Primavera Americana
# ...                                      ...
# 971360  Promoção Férias Escolares Americanas
# 971361  Promoção Férias Escolares Americanas
# 971362          Promoção de Férias Europeias
# 971363  Promoção Férias Escolares Americanas
# 971364          Promoção de Férias Europeias
#
# [971365 rows x 11 columns]

# %% [markdown]
# ### Agora podemos começar as análises

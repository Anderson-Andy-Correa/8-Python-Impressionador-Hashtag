# %% [markdown]
# # Adicionando Colunas, Modificando Colunas e Valores

# %% [markdown]
# ### Vamos pegar o nosso dataframe novamente

# %%
import pandas as pd
#importando os arquivos

pasta_referencia = r'.\Pandas 05 - Dados'
vendas_df    = pd.read_csv(fr'{pasta_referencia}\Contoso - Vendas - 2017.csv'    , sep=';', encoding='utf-8')
produtos_df  = pd.read_csv(fr'{pasta_referencia}\Contoso - Cadastro Produtos.csv', sep=';', encoding='ANSI')
lojas_df     = pd.read_csv(fr'{pasta_referencia}\Contoso - Lojas.csv'            , sep=';', encoding='ANSI')
clientes_df  = pd.read_csv(fr'{pasta_referencia}\Contoso - Clientes.csv'         , sep=';', encoding='ANSI')
promocoes_df = pd.read_csv(fr'{pasta_referencia}\Contoso - Promocoes.csv'        , sep=';', encoding='ANSI')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 971360           980638    31/12/2017    31/12/2017         0      194
# 971361           980639    31/12/2017    06/01/2018         6       32
# 971362           980640    31/12/2017    03/01/2018         3      210
# 971363           980641    31/12/2017    31/12/2017         0       53
# 971364           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0              981            2        6825                   9
# 1             1586            2       18469                   9
# 2             1444            5       19730                  13
# 3             1468            5       29326                   6
# 4             1106            2       22617                   4
# ...            ...          ...         ...                 ...
# 971360        2490            4       10353                 120
# 971361        2488            4       31750                 120
# 971362        2511           10       12003                  80
# 971363         436            4       25550                  39
# 971364        2510           10       28707                  80
#
#         Quantidade Devolvida  \
# 0                          1
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ...                      ...
# 971360                     0
# 971361                     0
# 971362                     0
# 971363                     0
# 971364                     0
#
#                                           Nome do Produto  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1                   SV DVD 55DVD Storage Binder M56 Black
# 2       The Phone Company Touch Screen Phones 26-2.2" ...
# 3             Contoso Touch Screen Phones - CRT M11 Black
# 4                          Contoso SLR Camera M146 Orange
# ...                                                   ...
# 971360      Contoso Rubberized Skin BlackBerry E100 White
# 971361      Contoso Rubberized Skin BlackBerry E100 Black
# 971362  Contoso Original K1m Li-Ion Standard Battery E...
# 971363         Adventure Works Desktop PC1.80 ED180 White
# 971364  Contoso Original K1m Li-Ion Standard Battery E...
#
#                                Nome da Loja             E-mail do Cliente
# 0                      Loja Contoso Austin         rbrumfieldmy@ameblo.jp
# 1       Loja Contoso North America Reseller        cshawd4@technorati.com
# 2                 Loja Contoso Tehran No.2         kgorriekd@bandcamp.com
# 3                   Loja Contoso Singapore   angela49@adventure-works.com
# 4               Loja Contoso Grand Prairie     jacob4@adventure-works.com
# ...                                     ...                           ...
# 971360                Loja Contoso Ridgely        ocrosson9u@illinois.edu
# 971361               Loja Contoso Milliken   victor11@adventure-works.com
# 971362               Loja Contoso Cheshire               mtopaz4@gmpg.org
# 971363              Loja Contoso East Troy     lance5@adventure-works.com
# 971364         Loja Contoso Europe Reseller      jan8@adventure-works.com
#
# [971365 rows x 13 columns]

# %%
vendas_df.info()

# %% [markdown]
# ### Agora, e se quisermos acrescentar uma coluna com o mês, o dia e o ano de cada venda (e não só a data completa)

# %%
vendas_df['Data da Venda'] = pd.to_datetime(vendas_df['Data da Venda'], format='%d/%m/%Y')
vendas_df['Ano da Venda']  = vendas_df['Data da Venda'].dt.year
vendas_df['Mes da Venda']  = vendas_df['Data da Venda'].dt.month
vendas_df['Dia da Venda']  = vendas_df['Data da Venda'].dt.day

vendas_df['Data do Envio'] = pd.to_datetime(vendas_df['Data do Envio'], format='%d/%m/%Y')
vendas_df['Ano da Envio']  = vendas_df['Data do Envio'].dt.year
vendas_df['Mes da Envio']  = vendas_df['Data do Envio'].dt.month
vendas_df['Dia da Envio']  = vendas_df['Data do Envio'].dt.day

vendas_df  = vendas_df.drop(columns=['Data da Venda', 'Data do Envio'])
display(vendas_df)
vendas_df.info()
# Out:
#         Numero da Venda  ID Canal  ID Loja  ID Produto  ID Promocao  \
# 0                     1         1       86         981            2
# 1                     2         5      308        1586            2
# 2                     3         0      294        1444            5
# 3                     4         0      251        1468            5
# 4                     5         6       94        1106            2
# ...                 ...       ...      ...         ...          ...
# 971360           980638         0      194        2490            4
# 971361           980639         6       32        2488            4
# 971362           980640         3      210        2511           10
# 971363           980641         0       53         436            4
# 971364           980642         0      309        2510           10
#
#         ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0             6825                   9                     1
# 1            18469                   9                     1
# 2            19730                  13                     1
# 3            29326                   6                     1
# 4            22617                   4                     1
# ...            ...                 ...                   ...
# 971360       10353                 120                     0
# 971361       31750                 120                     0
# 971362       12003                  80                     0
# 971363       25550                  39                     0
# 971364       28707                  80                     0
#
#                                           Nome do Produto  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1                   SV DVD 55DVD Storage Binder M56 Black
# 2       The Phone Company Touch Screen Phones 26-2.2" ...
# 3             Contoso Touch Screen Phones - CRT M11 Black
# 4                          Contoso SLR Camera M146 Orange
# ...                                                   ...
# 971360      Contoso Rubberized Skin BlackBerry E100 White
# 971361      Contoso Rubberized Skin BlackBerry E100 Black
# 971362  Contoso Original K1m Li-Ion Standard Battery E...
# 971363         Adventure Works Desktop PC1.80 ED180 White
# 971364  Contoso Original K1m Li-Ion Standard Battery E...
#
#                                Nome da Loja             E-mail do Cliente  \
# 0                      Loja Contoso Austin         rbrumfieldmy@ameblo.jp
# 1       Loja Contoso North America Reseller        cshawd4@technorati.com
# 2                 Loja Contoso Tehran No.2         kgorriekd@bandcamp.com
# 3                   Loja Contoso Singapore   angela49@adventure-works.com
# 4               Loja Contoso Grand Prairie     jacob4@adventure-works.com
# ...                                     ...                           ...
# 971360                Loja Contoso Ridgely        ocrosson9u@illinois.edu
# 971361               Loja Contoso Milliken   victor11@adventure-works.com
# 971362               Loja Contoso Cheshire               mtopaz4@gmpg.org
# 971363              Loja Contoso East Troy     lance5@adventure-works.com
# 971364         Loja Contoso Europe Reseller      jan8@adventure-works.com
#
#         Ano da Venda  Mes da Venda  Dia da Venda  Ano da Envio  Mes da Envio  \
# 0               2017             1             1          2017             1
# 1               2017             1             1          2017             1
# 2               2017             1             1          2017             1
# 3               2017             1             1          2017             1
# 4               2017             1             1          2017             1
# ...              ...           ...           ...           ...           ...
# 971360          2017            12            31          2017            12
# 971361          2017            12            31          2018             1
# 971362          2017            12            31          2018             1
# 971363          2017            12            31          2017            12
# 971364          2017            12            31          2017            12
#
#         Dia da Envio
# 0                  2
# 1                  6
# 2                  1
# 3                  1
# 4                  7
# ...              ...
# 971360            31
# 971361             6
# 971362             3
# 971363            31
# 971364            31
#
# [971365 rows x 17 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971365 entries, 0 to 971364
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       971365 non-null  int64
#  1   ID Canal              971365 non-null  int64
#  2   ID Loja               971365 non-null  int64
#  3   ID Produto            971365 non-null  int64
#  4   ID Promocao           971365 non-null  int64
#  5   ID Cliente            971365 non-null  int64
#  6   Quantidade Vendida    971365 non-null  int64
#  7   Quantidade Devolvida  971365 non-null  int64
#  8   Nome do Produto       971365 non-null  object
#  9   Nome da Loja          971365 non-null  object
#  10  E-mail do Cliente     971365 non-null  object
#  11  Ano da Venda          971365 non-null  int32
#  12  Mes da Venda          971365 non-null  int32
#  13  Dia da Venda          971365 non-null  int32
#  14  Ano da Envio          971365 non-null  int32
#  15  Mes da Envio          971365 non-null  int32
#  16  Dia da Envio          971365 non-null  int32
# dtypes: int32(6), int64(8), object(3)
# memory usage: 103.8+ MB

# %% [markdown]
# ### E agora, caso a gente queira modificar 1 valor específico, como fazemos? Vamos importar novamente a base de produtos

# %%
novo_produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
display(novo_produtos_df.head())
#repare no .head() para pegar apenas os primeiros valores, é bem comum esse uso para ter uma visão do que são os dados

# %% [markdown]
# ### Antes de entrar no próximo exemplo, precisamos falar de 2 métodos:
#     1. loc - permite pegar uma linha de acordo com o índice dela. Ele dá erro caso não encontre o índice. Isso é interessante principalmente quando o índice é uma informação relevante ao invés só do número do índice ou quando queremos pegar alguma linha específica do dataframe (ao invés de ir do início do dataframe até a linha 5, por exemplo).
#         Também podemos usar como loc[índice_linha, índice_coluna] para acessar um valor específico e modificá-lo.
#     2. iloc - enxerga o dataframe como linhas e colunas e consegue pegar o valor com um número de linha e um número de coluna. Repara que ele não analisa o valor do índice da linha e da coluna, apenas a posição importa.
#         Uso: iloc[num_linha, num_coluna]
#
# - Vendo na prática

# %%
novo_produtos_df = novo_produtos_df.set_index('Nome do Produto')
display(novo_produtos_df.head())

# %%
#vamos pegar o preço produto Contoso Optical Wheel OEM PS/2 Mouse E60 Black
#por loc

#por iloc

# %% [markdown]
# ### A empresa decidiu aumentar o preço do produto ID 873 (Contoso Wireless Laser Mouse E50 Grey) para 23 reais. Como fazemos, para modificar isso na nossa base?

# %%
#novo_produtos_df.loc['Contoso Wireless Laser Mouse E50 Grey', 'Preco Unitario'] = 23
